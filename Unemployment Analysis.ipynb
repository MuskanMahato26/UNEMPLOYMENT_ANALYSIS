# %% [markdown]
# # ***UNEMPLOYMENT ANALYSIS WITH PYTHON***
#
# Unemployment is measured by the unemployment rate which is the number of people who are unemployed as a percentage of the total labour force. We have seen a sharp increase in the unemployment rate during Covid-19, so analyzing the unemployment rate can be a good data science project.

# %%
#importing libraries

# %% [markdown]
# ** NumPy** is a powerful library for numerical operations in Python, providing support for large, multi-dimensional arrays and matrices, along with mathematical functions to operate on these arrays
#
#  **Pandas** is a data manipulation and analysis library that provides data structures like DataFrames, which are useful for working with structured data
#
#  **Matplotlib** is a popular plotting library in Python, and pyplot provides a simple interface for creating various types of plots and charts
#
#   **Seaborn** library which is built on top of Matplotlib and provides an additional set of aesthetic and statistical enhancements for creating appealing and informative statistical graphics
#
#
#    **Plotly Express** is a high-level interface for creating a variety of interactive plots. It simplifies the process of creating complex visualizations with a concise syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#read data

# %%
data = pd.read_csv("Unemployment in India.csv")
data2020=pd.read_csv("Unemployment_Rate_upto_11_2020.csv")
print(data.head())
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
print(data2020.head())
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
data2020.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
#Estimated Labour Participation Rate:
#The Labour Participation Rate (LPR) is the percentage of the working-age population (people who are either employed or actively seeking employment) that is either employed or actively looking for work.
#It is calculated as the sum of employed individuals and those actively seeking employment divided by the total working-age population, multiplied by 100.
#A higher labour participation rate generally indicates a larger proportion of the population actively involved in the labor market.

 #Estimated Employed:
#This refers to the number of people who are currently employed in the workforce.
#It includes individuals who have jobs, regardless of whether they are working full-time, part-time, or in temporary positions.

 #Estimated Unemployment Rate:
#The Unemployment Rate is the percentage of the labor force that is unemployed and actively seeking employment.
#It is calculated as the number of unemployed individuals divided by the total labor force (the sum of employed and unemployed individuals), multiplied by 100.
#A higher unemployment rate indicates a higher proportion of the labor force without employment.

# %%
print(data.describe)
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
print(data2020.describe)
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
#checking if the dataset contaims missing values(null value) or not using null function & .sum function which tells the columns having null values

# %%
print(data.isnull().sum())
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
print(data2020.isnull().sum())
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
#Dropping the null value
# a popular Python data manipulation library .dropna() function used to remove missing values from a DataFrame

# %%
data_cleaned = data.dropna()

# This will create a new DataFrame 'data_cleaned' with missing values removed.

# %%
print(data_cleaned.isnull().sum())
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
#renaming all the columns which is not so prominent

# %%
data_cleaned.columns =["States", "Date", "Frequency", "Estimated Unemployment Rate",
                       "Estimated Employed","Estimated Labour Participation Rate",
                       "Region"]

# %%
print(data_cleaned)
# Out:
#              States         Date Frequency  Estimated Unemployment Rate  \
# 0    Andhra Pradesh   31-05-2019   Monthly                         3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                         3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                         3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                         3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                         5.17
# ..              ...          ...       ...                          ...
# 749     West Bengal   29-02-2020   Monthly                         7.55
# 750     West Bengal   31-03-2020   Monthly                         6.67
# 751     West Bengal   30-04-2020   Monthly                        15.63
# 752     West Bengal   31-05-2020   Monthly                        15.22
# 753     West Bengal   30-06-2020   Monthly                         9.86
#
#      Estimated Employed  Estimated Labour Participation Rate Region
# ...

# %%
#checking the correlation between the features of the dataset
#using matplotlib to visualize the data
#Seaborn style with a white background and grid lines,stylistic choice and doesn't affect the functionality of the plot
#plt.figure(figsize=(12,10))=>creates a new figure with a specified size width is 12 units and the height is 10 units
#sns.heatmap(data.corr())=> creates a heatmap using the Seaborn library. data.corr() calculates the correlation matrix for the numerical columns
# sns.heatmap=>visualizes this matrix as a heatmap
#plt.show() to display the plot

# %%
plt.style.use("seaborn-whitegrid")
plt.figure(figsize=(6,6))
sns.heatmap(data.corr())
plt.show()
# Out:
# <ipython-input-70-e12a7f60b79c>:1: MatplotlibDeprecationWarning:
#
# The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#
# <ipython-input-70-e12a7f60b79c>:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
#Visualize the data and analyze the unemployment rate
   #look at the estimated number of employees according to different regions of india.

# %%
data_cleaned.columns =["States", "Date", "Frequency", "Estimated Unemployment Rate",
                       "Estimated Employed","Estimated Labour Participation Rate",
                       "Region"]
plt.title("India's Unemployment")
sns.histplot(x="Estimated Employed", hue="Region", data=data_cleaned)
plt.show()

# %%
#see the unemployment rate according to different regions of india.

# %%
data_cleaned.columns =["States", "Date", "Frequency", "Estimated Unemployment Rate",
                       "Estimated Employed","Estimated Labour Participation Rate",
                       "Region"]
plt.figure(figsize=(10,8))
plt.title("India's Unemployment")
sns.histplot(x="Estimated Unemployment Rate", hue="Region", data =data_cleaned)
plt.show()

# %%
# Matplotlib subplot
fig = plt.figure()
axe = fig.add_subplot(1, 2, 1)

# Top 10 States with highest unemployment using Matplotlib
data_cleaned[:10].plot(kind='bar', color='red', figsize=(30, 5), ax=axe)

axe.set_title('Top 10 States with highest unemployment')
axe.set_xlabel('States')
axe.set_ylabel('Estimated Unemployment Rate')
# Out:
# Text(0, 0.5, 'Estimated Unemployment Rate')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

# Bar plot for Labor Participation Rate
axes[0].bar(data_cleaned["Date"], data_cleaned["Estimated Labour Participation Rate"], color='blue', label='Labor Participation Rate')
axes[0].set_title('Labor Participation Rate Each Month')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Estimated Labor Participation Rate (%)')
axes[0].legend()

# Bar plot for Unemployment Rate
axes[1].bar(data_cleaned["Date"], data_cleaned["Estimated Unemployment Rate"], color='red', label='Unemployment Rate')
axes[1].set_title('Unemployment Rate Each Month')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Estimated Unemployment Rate')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
#Creating a dashboard to analyze the unemployment rate each indian state with region

# %%
unemployment= data_cleaned[["States", "Region", "Estimated Unemployment Rate"]]
figure = px.sunburst(unemployment, path=["Region","States"],
                   values="Estimated Unemployment Rate",
                   width=900, height=700,
                   title="Unemployment Rate in India")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data2020.columns =["States", "Date", "Frequency", "Estimated Unemployment Rate",
                       "Estimated Employed","Estimated Labour Participation Rate",
                       "Region","longitude ","latitude"]
unemployment1= data2020[[ "States", "Region", "Estimated Unemployment Rate"]]
figure1 = px.sunburst(unemployment1, path=["Region","States"],
                   values="Estimated Unemployment Rate",
                   width=900, height=700,
                   title="Unemployment Rate in India")
figure1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
